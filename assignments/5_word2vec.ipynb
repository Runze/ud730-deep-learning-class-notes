# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename +
                        '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):    
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000


def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        # `dictionary` is a dict that maps a word to an index number
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        # `data` simply stores the index number to a word
        data.append(index)
    count[0][1] = unk_count
    # `reverse_dictionary` maps an index number back to a word
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0


def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(
        batch_size=8, num_skips=num_skips, skip_window=skip_window)
    
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution (i.e., top 100).
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64  # Number of negative examples to sample (for sampled softmax).

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights,
            biases=softmax_biases,
            inputs=embed,
            labels=train_labels,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(valid_embeddings,
                           tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]  # excluding the validation word itself
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.043013
# Nearest to up: suited, binitarianism, whitehall, immunoglobulin, increments, helices, larp, ditko,
# Nearest to s: hanjour, cody, tra, vedas, inclinations, hatton, spurring, thunderbolt,
# Nearest to there: drachmae, shifter, concert, unpredictable, remaining, dwan, phi, nmt,
# Nearest to world: panes, criticise, noble, antiarrhythmic, severance, clonic, barracks, expansionary,
# Nearest to their: response, kilobyte, ni, mejid, lactantius, dordrecht, augusto, preceding,
# Nearest to nine: speaker, assortment, dogme, imitating, cruel, cyrene, trust, visitation,
# Nearest to with: severe, ethics, detours, statics, aris, hospitals, scrolling, kombinate,
# Nearest to a: chromic, wexford, success, contenders, potentially, arb, segmented, shigeru,
# Nearest to from: wicked, ll, zz, purportedly, zhaozhou, gloom, cordial, caddy,
# Nearest to was: sends, overuse, autocorrelation, conduit, spires, jeffery, giving, correspondents,
# Nearest to for: falsified, postage, through, kuala, sata, account, thrones, biophysics,
# Nearest to four: insightful, exceeding, wizards, coerced, waning, afghana, emet, glues,
# Nearest to only: endows, rabbis, budge, tata, untreated, evading, wishbone, chukotka,
# Nearest to no: poachers, commercials, proposes, agriculture, schaeffer, flooding, ecstatic, transcribe,
# Nearest to i: maoists, acorns, stanshall, eusebius, gielgud, rightarrow, entitled, arc,
# Nearest to is: tutorials, manuscripts, holborn, vows, estudios, functionally, humankind, muad,
# Average loss at step 2000: 4.370262
# Average loss at step 4000: 3.864441
# Average loss at step 6000: 3.793955
# Average loss at step 8000: 3.693707
# Average loss at step 10000: 3.615958
# Nearest to up: explication, immunoglobulin, selwyn, obrzeg, glorious, ipswich, hrothgar, only,
# Nearest to s: his, and, the, furies, atemi, widdecombe, dogg, bras,
# Nearest to there: it, they, not, also, he, phi, remaining, often,
# Nearest to world: panes, fare, clonic, noble, cao, severance, antiarrhythmic, herman,
# Nearest to their: his, its, tanya, xie, the, orphaned, knows, couch,
# Nearest to nine: eight, seven, five, six, four, zero, three, two,
# Nearest to with: in, by, between, during, wipe, anecdote, disallow, governs,
# Nearest to a: the, this, harpsichords, bhumi, irishman, prejudiced, saskatchewan, lyricists,
# Nearest to from: ll, in, by, sfor, of, pda, into, wicked,
# Nearest to was: is, has, by, were, had, apsu, be, sends,
# Nearest to for: in, of, weak, using, livius, tammy, multi, with,
# Nearest to four: six, eight, three, seven, five, two, nine, zero,
# Nearest to only: cuttlefish, heil, coffey, researched, up, lewisham, snapped, rabbis,
# Nearest to no: it, shipbuilding, flooding, transcribe, agriculture, straight, lied, santer,
# Nearest to i: they, conquering, cataloguing, colonialism, bskyb, airlift, rabinowitz, carlin,
# Nearest to is: was, are, has, does, can, apsu, be, enthusiastically,
# Average loss at step 12000: 3.604120
# Average loss at step 14000: 3.575581
# Average loss at step 16000: 3.413043
# Average loss at step 18000: 3.459728
# Average loss at step 20000: 3.537582
# Nearest to up: explication, selwyn, obrzeg, out, being, glorious, ipswich, immunoglobulin,
# Nearest to s: attenuation, frac, suzaku, resident, haig, bike, fetuses, di,
# Nearest to there: it, they, he, often, which, still, also, disturbed,
# Nearest to world: fare, elemental, round, clonic, panes, cao, noble, barracks,
# Nearest to their: his, its, the, her, xie, them, reopening, heflin,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to with: between, in, by, for, during, or, disallow, geoid,
# Nearest to a: the, this, nea, another, no, very, regulated, tanakh,
# Nearest to from: in, into, at, between, by, aussie, through, and,
# Nearest to was: is, has, were, had, sends, giving, apsu, became,
# Nearest to for: through, in, with, of, creamy, by, or, ppg,
# Nearest to four: six, seven, five, three, eight, nine, two, zero,
# Nearest to only: lewisham, tan, pandemic, stabilized, tano, being, considered, ouadda,
# Nearest to no: straight, transcribe, a, largely, shipbuilding, hesitated, lied, laughing,
# Nearest to i: ii, colonialism, conquering, unworkable, bent, primitive, rebound, tilted,
# Nearest to is: was, has, are, gravesite, does, be, were, if,
# Average loss at step 22000: 3.504925
# Average loss at step 24000: 3.487842
# Average loss at step 26000: 3.478411
# Average loss at step 28000: 3.480492
# Average loss at step 30000: 3.504163
# Nearest to up: explication, him, out, selwyn, them, trousers, belong, expelling,
# Nearest to s: his, suzaku, and, noir, tallinn, emerged, motorists, remission,
# Nearest to there: they, it, he, often, still, disturbed, which, now,
# Nearest to world: fare, clonic, elemental, nigger, montaigne, civil, noble, phenotypes,
# Nearest to their: its, his, the, her, some, these, heflin, xie,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to with: between, in, by, when, wray, from, into, vyasa,
# Nearest to a: the, any, no, nea, namely, mitsuda, namesake, vanadium,
# Nearest to from: into, in, by, under, between, aussie, of, through,
# Nearest to was: is, had, has, were, became, sends, does, interchangeably,
# Nearest to for: multi, with, after, to, through, thunderbirds, eiji, as,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to only: lewisham, irradiation, generally, tan, spouse, increasingly, nfs, it,
# Nearest to no: largely, still, transcribe, it, any, shipbuilding, lied, a,
# Nearest to i: ii, we, they, you, rebound, bent, unworkable, g,
# Nearest to is: was, has, are, if, does, interchangeably, mirror, although,
# Average loss at step 32000: 3.504354
# Average loss at step 34000: 3.492982
# Average loss at step 36000: 3.456680
# Average loss at step 38000: 3.304451
# Average loss at step 40000: 3.425519
# Nearest to up: out, him, them, explication, selwyn, trousers, sentinel, belong,
# Nearest to s: his, attenuation, nanjing, remission, solzhenitsyn, schaefer, did, noir,
# Nearest to there: it, they, he, often, now, still, which, also,
# Nearest to world: civil, elemental, fare, swaim, clonic, montaigne, kalmar, round,
# Nearest to their: its, his, her, the, some, these, them, heflin,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to with: between, in, by, when, ejecta, from, for, soda,
# Nearest to a: the, another, irishman, no, harpsichords, potencies, any, vanadium,
# Nearest to from: into, through, ll, aussie, in, negative, between, since,
# Nearest to was: is, has, had, became, were, been, interchangeably, does,
# Nearest to for: if, using, gaetano, livius, in, ium, through, multi,
# Nearest to four: six, seven, five, three, eight, nine, two, zero,
# Nearest to only: lewisham, spouse, it, around, irradiation, increasingly, trust, delicately,
# Nearest to no: any, largely, still, holborn, hesitated, actually, agriculture, a,
# Nearest to i: we, ii, you, they, he, t, rebound, freeman,
# Nearest to is: was, are, has, if, be, remains, confrontation, when,
# Average loss at step 42000: 3.436910
# Average loss at step 44000: 3.453885
# Average loss at step 46000: 3.454510
# Average loss at step 48000: 3.351197
# Average loss at step 50000: 3.386543
# Nearest to up: out, them, him, off, trousers, explication, belong, sentinel,
# Nearest to s: his, whose, and, beard, humiliating, preludes, hermon, remission,
# Nearest to there: it, they, he, now, who, still, she, often,
# Nearest to world: civil, elemental, boil, fare, tegmark, molly, european, kalmar,
# Nearest to their: its, his, her, the, your, some, these, landowner,
# Nearest to nine: seven, eight, six, four, five, three, zero, two,
# Nearest to with: between, in, astronomical, ejecta, bil, vyasa, after, sparking,
# Nearest to a: another, the, antecedent, any, ancona, vanadium, sausages, little,
# Nearest to from: into, through, under, in, throughput, between, aussie, until,
# Nearest to was: is, has, became, were, had, sends, be, been,
# Nearest to for: multi, while, posthumous, including, through, after, toon, hanlon,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to only: lewisham, armistice, purification, water, since, irradiation, harness, around,
# Nearest to no: any, banco, largely, exarchate, considerably, himalayan, santer, saving,
# Nearest to i: we, ii, you, iucn, t, rebound, freeman, iii,
# Nearest to is: was, are, has, does, became, faro, gravesite, tampa,
# Average loss at step 52000: 3.435586
# Average loss at step 54000: 3.426800
# Average loss at step 56000: 3.437396
# Average loss at step 58000: 3.398270
# Average loss at step 60000: 3.399812
# Nearest to up: out, them, him, off, down, back, together, expelling,
# Nearest to s: whose, ewe, awm, stoney, tipu, bonobo, rotational, fraught,
# Nearest to there: it, they, now, he, still, this, she, often,
# Nearest to world: european, civil, elemental, fare, dangers, tegmark, boil, phenotypes,
# Nearest to their: its, his, her, the, your, our, them, some,
# Nearest to nine: eight, six, seven, four, five, zero, three, one,
# Nearest to with: between, by, misgivings, jungle, vyasa, in, within, when,
# Nearest to a: another, any, the, every, ancona, vanadium, no, ene,
# Nearest to from: into, through, aussie, cordial, including, in, throughput, seeger,
# Nearest to was: is, had, became, has, were, although, been, sends,
# Nearest to for: including, of, multi, using, gaetano, if, posthumous, although,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to only: purification, every, first, lewisham, around, water, swain, until,
# Nearest to no: any, banco, considerably, psychometrics, saving, a, asterism, transcribe,
# Nearest to i: ii, we, you, iucn, freeman, iii, sidi, they,
# Nearest to is: was, are, has, although, remains, becomes, became, be,
# Average loss at step 62000: 3.238309
# Average loss at step 64000: 3.258375
# Average loss at step 66000: 3.405849
# Average loss at step 68000: 3.396041
# Average loss at step 70000: 3.357086
# Nearest to up: out, them, off, him, down, collagen, forward, expelling,
# Nearest to s: whose, shakur, assistants, or, attenuation, the, hanse, incised,
# Nearest to there: they, it, now, still, he, she, often, generally,
# Nearest to world: elemental, fare, civil, dangers, obscene, mastery, oop, hotspots,
# Nearest to their: its, his, her, the, your, some, our, these,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to with: between, misgivings, including, fidonet, ejecta, from, sparking, disallow,
# Nearest to a: the, another, any, enough, sla, nea, antecedent, harpsichords,
# Nearest to from: through, into, in, between, by, across, cordial, with,
# Nearest to was: is, were, has, had, became, been, sends, being,
# Nearest to for: in, including, gaetano, through, if, multi, of, using,
# Nearest to four: five, six, eight, three, seven, nine, zero, two,
# Nearest to only: lewisham, purification, never, every, still, directly, trivially, generally,
# Nearest to no: banco, considerably, any, little, scored, transcribe, asterism, there,
# Nearest to i: ii, we, you, g, freeman, iucn, unicef, sidi,
# Nearest to is: was, has, are, be, does, although, gravesite, remains,
# Average loss at step 72000: 3.376006
# Average loss at step 74000: 3.344039
# Average loss at step 76000: 3.323596
# Average loss at step 78000: 3.358587
# Average loss at step 80000: 3.374386
# Nearest to up: out, them, off, down, him, together, back, forward,
# Nearest to s: nanjing, humiliating, sobieski, barbour, whose, solzhenitsyn, noir, galatea,
# Nearest to there: it, they, he, she, now, this, still, often,
# Nearest to world: elemental, civil, mastery, fare, premiership, obscene, dangers, puppet,
# Nearest to their: its, his, her, your, our, the, some, heflin,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to with: between, throughout, fidonet, in, jungle, tegucigalpa, geoid, including,
# Nearest to a: the, another, potencies, every, any, kamakura, nea, vanadium,
# Nearest to from: into, through, in, after, by, before, around, between,
# Nearest to was: is, became, had, were, has, sends, been, footwork,
# Nearest to for: including, multi, archetypal, against, through, when, workaround, although,
# Nearest to four: six, five, eight, seven, three, nine, two, zero,
# Nearest to only: lewisham, first, last, never, aged, until, depository, currently,
# Nearest to no: banco, any, little, considerably, jannah, psychometrics, relations, scored,
# Nearest to i: ii, we, you, g, sidi, freeman, t, mucus,
# Nearest to is: was, has, are, be, became, lies, although, were,
# Average loss at step 82000: 3.410639
# Average loss at step 84000: 3.412537
# Average loss at step 86000: 3.394195
# Average loss at step 88000: 3.351467
# Average loss at step 90000: 3.370980
# Nearest to up: out, off, down, them, him, together, back, forward,
# Nearest to s: whose, his, isbn, howlin, your, himmler, behaves, normand,
# Nearest to there: they, it, he, still, she, now, we, generally,
# Nearest to world: elemental, civil, improve, mastery, premiership, trafford, dangers, match,
# Nearest to their: its, his, her, your, our, them, the, some,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to with: between, in, fidonet, ejecta, bil, throughout, geoid, mutagenesis,
# Nearest to a: another, the, any, floating, injectors, dimmu, veritas, vanadium,
# Nearest to from: through, into, via, across, in, between, during, dizziness,
# Nearest to was: is, became, had, were, has, sends, been, being,
# Nearest to for: including, posthumous, of, multi, livius, occultation, without, after,
# Nearest to four: five, seven, eight, six, three, nine, two, zero,
# Nearest to only: lewisham, every, currently, roadway, aged, not, spouse, all,
# Nearest to no: any, banco, little, lifespans, only, considerably, psychometrics, dispersed,
# Nearest to i: ii, we, g, you, sidi, iii, freeman, mathbf,
# Nearest to is: was, has, are, becomes, boomed, became, although, requires,
# Average loss at step 92000: 3.397130
# Average loss at step 94000: 3.255274
# Average loss at step 96000: 3.359851
# Average loss at step 98000: 3.246654
# Average loss at step 100000: 3.357242
# Nearest to up: out, off, him, them, down, forward, together, back,
# Nearest to s: whose, his, humiliating, isbn, solzhenitsyn, your, tipu, the,
# Nearest to there: they, now, it, he, we, still, generally, usually,
# Nearest to world: premiership, elemental, european, mastery, lunar, ibm, civil, match,
# Nearest to their: its, his, her, your, our, the, these, some,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to with: between, including, in, wray, mutagenesis, when, whigs, into,
# Nearest to a: another, any, the, vanadium, enough, imperialism, mocking, floating,
# Nearest to from: through, into, between, in, within, across, throughput, via,
# Nearest to was: is, became, has, sends, had, were, becomes, been,
# Nearest to for: including, after, when, if, before, mahmoud, without, until,
# Nearest to four: seven, six, five, eight, three, nine, two, zero,
# Nearest to only: spouse, roadway, until, lewisham, never, every, silent, polyatomic,
# Nearest to no: little, any, banco, hjalmar, finalist, considerably, dispersed, minimal,
# Nearest to i: we, ii, you, they, iii, sidi, she, g,
# Nearest to is: was, has, became, lies, becomes, be, are, includes,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(np.asfarray(final_embeddings[1:num_points+1, :], dtype='float'))

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0


def generate_batch_cbow(batch_size, num_skips, skip_window):
    # in this implementation, I am simply going to
    # flip the results of the previous `generate_batch` function
    # which produces (word, context) pair
    
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size // num_skips, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
    
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        labels[i, 0] = buffer[skip_window]
        
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i, j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(
        batch_size=8, num_skips=num_skips, skip_window=skip_window)
    
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batches:', [[reverse_dictionary[bi] for bi in b] for b in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(-1)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batches: [['anarchism', 'as'], ['a', 'originated'], ['term', 'as'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
# [[3084]
#  [  12]
#  [   6]
#  [ 195]]
#
# with num_skips = 4 and skip_window = 2:
#     batches: [['originated', 'a', 'term', 'anarchism'], ['originated', 'of', 'term', 'as']]
#     labels: ['as', 'a']
# [[12]
#  [ 6]]

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

num_sampled = 64  # Number of negative examples to sample (for sampled softmax).

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size // num_skips, num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size // num_skips, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal(
            [vocabulary_size, embedding_size],
            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(
            weights=softmax_weights,
            biases=softmax_biases,
            inputs=tf.reduce_sum(embed, 1),  # compute "the sum of all the word vectors in its context"
            labels=train_labels,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(valid_embeddings,
                           tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_cbow(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]  # excluding the validation word itself
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.995933
# Nearest to of: conducted, palatal, owl, optimism, knut, regrettable, clowns, farthest,
# Nearest to who: franchisees, repression, stepfather, painter, debilitating, theophoric, mitochondria, abi,
# Nearest to used: settlers, decimated, canaria, delphic, swing, honky, irb, theorist,
# Nearest to that: censured, hellenistic, lets, sindhu, bilaterally, students, indefinitely, shorten,
# Nearest to they: esq, cuyp, lactamase, internment, assistant, nguyen, reinstating, mountaineering,
# Nearest to see: additions, aquariums, tanker, whispered, vetoed, requested, abbreviated, samsara,
# Nearest to one: insufficiently, lada, levellers, airman, nuit, designers, savannas, karzai,
# Nearest to most: niue, ukraine, pitcairn, bloodstream, competitive, wasted, elric, nothingness,
# Nearest to between: officer, modelling, ccny, kinderhook, political, intoxication, mistral, abwehr,
# Nearest to about: filesystem, mortis, pinpoint, mycenaean, ironworks, looser, memphis, colossus,
# Nearest to may: proportionately, subjugating, higher, pes, carrion, hurl, polyethylene, ecologists,
# Nearest to these: differing, vociferous, terran, stocked, errant, apparel, formulaic, integration,
# Nearest to called: cps, maneuvers, valves, canso, neuronal, funerary, purcell, subpixels,
# Nearest to nine: traverses, minya, reilly, modifier, emigration, drury, huntley, artisan,
# Nearest to state: heredity, myanmar, hexagram, absolute, dragging, warren, marquess, asquith,
# Nearest to as: apoptotic, dehydroepiandrosterone, clothing, followings, differences, refund, orange, intermolecular,
# Average loss at step 2000: 4.226114
# Average loss at step 4000: 3.638016
# Average loss at step 6000: 3.536184
# Average loss at step 8000: 3.383349
# Average loss at step 10000: 3.292721
# Nearest to of: in, at, habakkuk, mauretania, graceland, foreseeable, immerse, swell,
# Nearest to who: he, and, they, which, often, necropolis, she, takers,
# Nearest to used: known, found, considered, bartolomeo, called, regarded, koreans, filtered,
# Nearest to that: which, woodbridge, what, it, when, atop, lexemes, valdivia,
# Nearest to they: he, we, there, who, you, it, not, kilometre,
# Nearest to see: lg, abbreviated, omnia, but, clowns, mapmaking, unrounded, dg,
# Nearest to one: two, eight, three, outpatient, seven, four, courts, tsuburaya,
# Nearest to most: expulsion, dialysis, heterosexuals, some, carina, fokker, troop, more,
# Nearest to between: with, rna, starters, brancusi, sichuan, harpercollins, fari, officer,
# Nearest to about: professions, voyage, rao, mortis, synchronized, clays, rooting, reluctant,
# Nearest to may: can, would, will, might, must, could, should, centro,
# Nearest to these: errant, many, those, some, they, volume, such, port,
# Nearest to called: cnn, used, incompatibilities, cleopatra, postcards, campania, enzyme, polyhedron,
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to state: malt, comcast, natural, hexagram, asquith, diena, bd, influencing,
# Nearest to as: picks, antonov, junk, cx, tidy, jezreel, malwa, shing,
# Average loss at step 12000: 3.269986
# Average loss at step 14000: 3.236838
# Average loss at step 16000: 3.014482
# Average loss at step 18000: 3.061203
# Average loss at step 20000: 3.153894
# Nearest to of: in, foreseeable, for, joh, habakkuk, marwan, fdr, pelt,
# Nearest to who: often, he, which, still, she, necropolis, they, tippit,
# Nearest to used: known, found, called, filtered, published, written, necessary, referred,
# Nearest to that: when, which, but, lexemes, what, tim, cheeses, however,
# Nearest to they: we, there, he, she, it, you, who, then,
# Nearest to see: abbreviated, curls, omnia, known, bafta, stellar, sumerians, independents,
# Nearest to one: two, three, five, eight, seven, four, nine, six,
# Nearest to most: more, dialysis, some, expulsion, many, nothingness, evergreen, marienburg,
# Nearest to between: with, around, among, in, from, hammond, canes, perceptive,
# Nearest to about: rooting, phage, stabbing, earnest, tot, synchronized, safed, reluctant,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to these: some, such, many, several, those, which, errant, circuitry,
# Nearest to called: used, named, bruford, designed, referred, found, triphosphate, cnn,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to state: natural, gallup, computed, comcast, national, conservationist, vulpes, trade,
# Nearest to as: too, latent, rollins, junk, sopwith, mahmoud, motorcyclist, metaphor,
# Average loss at step 22000: 3.122654
# Average loss at step 24000: 3.075324
# Average loss at step 26000: 3.057621
# Average loss at step 28000: 3.068535
# Average loss at step 30000: 3.082389
# Nearest to of: in, among, for, against, olsen, including, luddites, besides,
# Nearest to who: she, he, which, they, now, it, trioxide, shoddy,
# Nearest to used: known, written, found, designed, necessary, required, employed, considered,
# Nearest to that: what, which, lexemes, if, konqueror, this, melcher, neri,
# Nearest to they: we, he, there, it, she, you, diacritical, who,
# Nearest to see: include, have, sumerians, banquets, sanitation, empowering, nuevo, abbreviated,
# Nearest to one: two, seven, nine, five, four, eight, six, three,
# Nearest to most: many, some, more, dialysis, among, marienburg, implementations, porto,
# Nearest to between: with, among, around, hammond, morris, ni, sichuan, perceptive,
# Nearest to about: enabling, earnest, melancholic, around, synchronized, on, ytv, motels,
# Nearest to may: can, would, will, must, could, might, should, cannot,
# Nearest to these: some, several, various, such, their, many, both, different,
# Nearest to called: considered, named, used, referred, sheen, bruford, pawns, conjugated,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to state: states, trade, gallup, computed, observant, influencing, government, kind,
# Nearest to as: sopwith, polyidus, picks, enraged, became, fuelled, nzenberg, without,
# Average loss at step 32000: 3.078447
# Average loss at step 34000: 3.050431
# Average loss at step 36000: 2.992437
# Average loss at step 38000: 2.798703
# Average loss at step 40000: 2.981529
# Nearest to of: for, gazette, foreseeable, jespersen, like, in, olsen, from,
# Nearest to who: often, she, he, which, also, they, necropolis, corroborated,
# Nearest to used: written, found, designed, known, given, seen, employed, considered,
# Nearest to that: which, what, however, this, tynwald, lexemes, ilya, urn,
# Nearest to they: we, you, he, there, she, it, not, these,
# Nearest to see: according, sanitation, references, include, abbreviated, stellar, interpolations, known,
# Nearest to one: seven, six, two, eight, nine, three, five, four,
# Nearest to most: more, very, less, evergreen, among, colchester, expulsion, caribbean,
# Nearest to between: with, within, hammond, regarding, among, adverse, in, trypanosoma,
# Nearest to about: inaccuracies, earnest, regards, professions, donny, bingham, smoker, shinoda,
# Nearest to may: can, will, must, might, could, would, should, cannot,
# Nearest to these: such, many, both, those, some, several, certain, they,
# Nearest to called: considered, named, used, referred, conjugated, where, currently, closed,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to state: government, comcast, computed, states, trade, city, kind, influencing,
# Nearest to as: preservatives, mahmoud, mutants, metaphor, too, dwight, malwa, overran,
# Average loss at step 42000: 2.981160
# Average loss at step 44000: 2.991745
# Average loss at step 46000: 2.974176
# Average loss at step 48000: 2.867197
# Average loss at step 50000: 2.891556
# Nearest to of: in, and, pelt, during, fewest, fait, including, joh,
# Nearest to who: he, she, which, they, often, never, now, also,
# Nearest to used: written, given, designed, known, referred, required, employed, seen,
# Nearest to that: which, however, what, this, kenyan, lexemes, often, where,
# Nearest to they: we, he, you, there, she, it, who, inquired,
# Nearest to see: include, stellar, according, references, including, interpolations, rpr, exhibited,
# Nearest to one: eight, two, seven, six, nine, four, three, five,
# Nearest to most: more, some, less, among, many, particularly, dialysis, expulsion,
# Nearest to between: with, within, hammond, among, regarding, anal, retells, fari,
# Nearest to about: filler, professions, fouling, over, bingham, synchronized, around, byrds,
# Nearest to may: must, would, might, can, should, could, will, cannot,
# Nearest to these: some, many, those, several, certain, various, such, both,
# Nearest to called: named, referred, surat, stra, yitzchak, used, wore, tudor,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to state: computed, states, comcast, kind, policy, interracial, municipal, city,
# Nearest to as: deluge, toyota, too, including, accordingly, endorsing, enraged, because,
# Average loss at step 52000: 2.949797
# Average loss at step 54000: 2.929051
# Average loss at step 56000: 2.954263
# Average loss at step 58000: 2.875217
# Average loss at step 60000: 2.897553
# Nearest to of: in, for, without, although, including, pelt, like, lovelock,
# Nearest to who: still, necropolis, now, which, rence, he, dialling, often,
# Nearest to used: written, designed, seen, referred, known, required, available, necessary,
# Nearest to that: which, what, this, there, where, melcher, woodbridge, shorten,
# Nearest to they: we, you, there, he, she, these, inquired, eichmann,
# Nearest to see: but, include, flask, granger, and, including, isc, refer,
# Nearest to one: seven, eight, four, two, nine, six, three, five,
# Nearest to most: less, many, dialysis, more, caribbean, some, especially, vocational,
# Nearest to between: with, within, among, in, around, furthering, hammond, fari,
# Nearest to about: around, regarding, giver, collectible, converse, loader, bringing, lieder,
# Nearest to may: can, must, will, should, could, would, might, cannot,
# Nearest to these: many, those, both, some, examples, they, which, such,
# Nearest to called: named, considered, referred, used, defined, known, designed, disapproved,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to state: government, kind, comcast, city, constitution, computed, resh, timeout,
# Nearest to as: hyped, mahmoud, mutants, infectors, tricking, sopwith, ideologically, metaphor,
# Average loss at step 62000: 2.675211
# Average loss at step 64000: 2.701494
# Average loss at step 66000: 2.873634
# Average loss at step 68000: 2.889561
# Average loss at step 70000: 2.831356
# Nearest to of: including, include, although, olsen, climatic, in, fewest, besides,
# Nearest to who: she, he, still, necropolis, rence, enzo, dialling, actually,
# Nearest to used: seen, referred, known, required, written, found, done, designed,
# Nearest to that: which, however, what, typically, this, where, there, serling,
# Nearest to they: we, there, he, you, she, it, popped, eichmann,
# Nearest to see: includes, include, curls, isc, treat, com, polanyi, theologiae,
# Nearest to one: two, seven, nine, eight, four, six, five, three,
# Nearest to most: more, less, many, evergreen, dialysis, particularly, some, alomari,
# Nearest to between: within, among, with, around, in, into, midgard, landon,
# Nearest to about: regarding, synchronized, loader, around, on, earnest, that, launchers,
# Nearest to may: would, might, can, will, should, could, must, cannot,
# Nearest to these: such, those, some, various, are, chifley, hp, many,
# Nearest to called: referred, named, considered, known, disapproved, stra, wore, termed,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to state: states, comcast, sagrada, replicating, government, summation, city, poor,
# Nearest to as: sopwith, mahmoud, hyped, before, glaser, boopsie, mensa, stadtholder,
# Average loss at step 72000: 2.860704
# Average loss at step 74000: 2.825042
# Average loss at step 76000: 2.816835
# Average loss at step 78000: 2.822861
# Average loss at step 80000: 2.855055
# Nearest to of: in, olsen, throughout, buyout, including, besides, clutching, include,
# Nearest to who: she, he, actually, which, rence, milanese, often, doublespeak,
# Nearest to used: seen, referred, given, required, known, defined, written, designed,
# Nearest to that: which, however, what, where, woodbridge, this, dinneen, stalinist,
# Nearest to they: we, he, you, there, she, it, eichmann, oud,
# Nearest to see: includes, references, theologiae, sanitation, refer, but, refers, known,
# Nearest to one: two, seven, four, eight, six, three, five, nine,
# Nearest to most: more, less, among, many, evergreen, some, particularly, expulsion,
# Nearest to between: within, among, with, over, through, starters, aix, davao,
# Nearest to about: synchronized, regarding, melancholic, filesystem, over, around, hales, expressing,
# Nearest to may: might, can, should, would, will, must, could, cannot,
# Nearest to these: several, various, those, many, some, such, chifley, numerous,
# Nearest to called: considered, referred, named, known, disapproved, termed, designed, produced,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to state: states, comcast, survey, city, government, replicating, public, summation,
# Nearest to as: chiao, glycosides, tsvetaeva, including, mahmoud, survivals, like, mutants,
# Average loss at step 82000: 2.882396
# Average loss at step 84000: 2.895474
# Average loss at step 86000: 2.855210
# Average loss at step 88000: 2.798988
# Average loss at step 90000: 2.816289
# Nearest to of: including, for, in, clutching, during, retard, olsen, underlying,
# Nearest to who: she, he, necropolis, milanese, which, dialling, enzo, russell,
# Nearest to used: referred, known, seen, applied, required, designed, defined, given,
# Nearest to that: which, what, melcher, however, heimdall, instead, but, midnight,
# Nearest to they: we, he, you, she, there, it, bagdad, juliet,
# Nearest to see: includes, references, isc, stellar, rawlinson, refer, apprentice, refers,
# Nearest to one: two, four, seven, eight, six, three, five, syrups,
# Nearest to most: less, more, among, some, many, conciliar, all, especially,
# Nearest to between: with, within, among, against, from, diaz, anal, across,
# Nearest to about: regarding, synchronized, on, faqs, flyby, concerning, filler, over,
# Nearest to may: should, must, might, can, would, could, will, cannot,
# Nearest to these: several, many, some, such, various, those, multiple, numerous,
# Nearest to called: referred, named, disapproved, considered, used, invent, known, entitled,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to state: states, replicating, comcast, survey, city, macroscopic, government, klang,
# Nearest to as: mahmoud, tsvetaeva, hekate, selene, including, mimi, cabinda, jezreel,
# Average loss at step 92000: 2.862599
# Average loss at step 94000: 2.691014
# Average loss at step 96000: 2.822394
# Average loss at step 98000: 2.694761
# Average loss at step 100000: 2.813175
# Nearest to of: including, besides, rajendra, by, abrasion, in, and, clutching,
# Nearest to who: he, milanese, which, initially, actually, necropolis, bal, hiddenstructure,
# Nearest to used: referred, applied, seen, sold, employed, designed, done, written,
# Nearest to that: which, what, however, when, melcher, macroevolution, where, how,
# Nearest to they: we, you, he, there, she, i, it, humans,
# Nearest to see: includes, refer, called, refers, according, allows, ssn, treat,
# Nearest to one: eight, two, seven, nine, four, three, five, six,
# Nearest to most: more, less, especially, particularly, evergreen, increasingly, dialysis, extremely,
# Nearest to between: among, within, with, across, around, over, hammond, against,
# Nearest to about: synchronized, regarding, faqs, on, filler, validating, fading, concerning,
# Nearest to may: might, should, must, can, would, could, will, cannot,
# Nearest to these: several, many, those, various, some, instead, which, lilongwe,
# Nearest to called: referred, named, termed, known, used, see, conjugated, mandola,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to state: stanford, comcast, states, girlfriend, city, congress, paranoia, sagrada,
# Nearest to as: mahmoud, tsvetaeva, allure, selene, stadtholder, like, motorcyclist, when,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(np.asfarray(final_embeddings[1:num_points+1, :], dtype='float'))

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15, 15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        pylab.scatter(x, y)
        pylab.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
    pylab.show()


words = [reverse_dictionary[i] for i in range(1, num_points + 1)]
plot(two_d_embeddings, words)
